# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
# %run dataset_gc.ipynb
# Out:
# DATASET LOADED
# EnterpriseModelDatasetGC(110)
# Processing...
# Done!

# %%
torch.manual_seed(42)
dataset = dataset_gc.shuffle()

print()
print(f'Dataset: {dataset}:')
print('====================')
print(f'Number of graphs: {len(dataset)}')
print(f'Number of features: {dataset.num_features}')
print(f'Number of classes: {dataset.num_classes}')
dataset[0]
# Out:
# Dataset: EnterpriseModelDatasetGC(110):
# ====================
# Number of graphs: 110
# Number of features: 1
# Number of classes: 9
# Data(x=[26, 1], edge_index=[2, 25], edge_attr=[25, 1], y=5)

# %%
torch.manual_seed(42)

balanced = False

while not balanced:
    dataset = dataset.shuffle()
    train_dataset = dataset[:int(len(dataset) * 0.6)]
    test_dataset = dataset[int(len(dataset) * 0.6):]
    
    train_ys = [0 for i in range(0,len(model_classes))]
    test_ys =[0 for i in range(0,len(model_classes))]

    for train_g in train_dataset:
        y = train_g.y
        train_ys[y] += 1


    for test_g in test_dataset:
        y = test_g.y
        test_ys[y] += 1
        
    if(0 not in train_ys and 1 not in train_ys and 0 not in test_ys and 1 not in test_ys):
        balanced = True


print(train_ys)
print(test_ys)
print("Datasets balanced!")

print(f'Number of graphs total: {len(dataset)}')
print(f'Number of training graphs: {len(train_dataset)}')
print(f'Number of test graphs: {len(test_dataset)}')
# Out:
# [7, 7, 5, 7, 4, 5, 25, 4, 2]
# [4, 3, 2, 5, 6, 2, 18, 2, 2]
# Datasets balanced!
# Number of graphs total: 110
# Number of training graphs: 66
# Number of test graphs: 44

# %%
from torch_geometric.loader import DataLoader

NUM_GRAPHS_PER_BATCH = 8
NUM_HIDDEN_CHANNELS = 32

train_loader = DataLoader(train_dataset, batch_size=NUM_GRAPHS_PER_BATCH, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=NUM_GRAPHS_PER_BATCH, shuffle=False)

# %%
from torch.nn import Linear
import torch.nn.functional as F
from torch_geometric.nn import GCNConv, GraphConv, SAGEConv, GATConv
from torch_geometric.nn import global_mean_pool


class GCN(torch.nn.Module):
    def __init__(self, hidden_channels):
        super(GCN, self).__init__()
        torch.manual_seed(42)
        self.conv1 = SAGEConv(dataset.num_node_features, 2 * hidden_channels)
        self.conv2 = SAGEConv(2 * hidden_channels, 4 *  hidden_channels)
        self.conv3 = SAGEConv(4 * hidden_channels, 2 * hidden_channels)
        self.lin1 = Linear(2 * hidden_channels, hidden_channels)
        self.lin2 = Linear(hidden_channels, dataset.num_classes)

    def forward(self, x, edge_index, batch):
        x = self.conv1(x, edge_index)
        x = x.relu()
        x = self.conv2(x, edge_index)
        x = x.relu()
        x = self.conv3(x, edge_index)

        x = global_mean_pool(x, batch)  # [batch_size, hidden_channels]

        x = F.dropout(x, p=0.5, training=self.training)
        x = self.lin1(x)
        x = self.lin2(x)
        return x

# %%
model = GCN(hidden_channels=NUM_HIDDEN_CHANNELS)
print(model)
print("Number of parameters: ", sum(p.numel() for p in model.parameters()))

optimizer = torch.optim.Adam(model.parameters(), lr=0.005)
criterion = torch.nn.CrossEntropyLoss()

def train():
    model.train()

    for data in train_loader:
        out = model(data.x, data.edge_index, data.batch)
        loss = criterion(out, data.y)
        loss.backward()
        optimizer.step()
        optimizer.zero_grad()
        return loss

def test(loader):
    model.eval()
    correct = 0
    for data in loader:
        out = model(data.x, data.edge_index, data.batch)  
        pred = out.argmax(dim=1)
        correct += int((pred == data.y).sum())
    return correct / len(loader.dataset)

loss_values = []
train_acc_values = []
acc_values = []

for epoch in range(1, 201):
    loss = train()
    train_acc = test(train_loader)
    test_acc = test(test_loader)
        
    loss_values.append(loss)
    acc_values.append(test_acc)
    train_acc_values.append(train_acc)
    print(f'Epoch: {epoch:03d}, Loss: {loss:.4f}, Train Acc: {train_acc:.4f}, Test Acc: {test_acc:.4f}')
    if(test_acc > 0.81):
        break

plt.plot(acc_values, 'b', train_acc_values, 'g')
#plt.savefig('acc_gc.png')
plt.show()

losses = [loss_values[i].item() for i in range(0, len(loss_values))]
plt.plot(losses, 'r')
#plt.savefig('loss_gc.png')
plt.show()
# Out:
# GCN(
#   (conv1): SAGEConv(1, 64)
#   (conv2): SAGEConv(64, 128)
#   (conv3): SAGEConv(128, 64)
#   (lin1): Linear(in_features=64, out_features=32, bias=True)
#   (lin2): Linear(in_features=32, out_features=9, bias=True)
# )
# Number of parameters:  35529
# Epoch: 001, Loss: 3.6583, Train Acc: 0.3788, Test Acc: 0.4091
# Epoch: 002, Loss: 1.7636, Train Acc: 0.3788, Test Acc: 0.4091
# Epoch: 003, Loss: 2.0850, Train Acc: 0.3788, Test Acc: 0.4318
# Epoch: 004, Loss: 2.1683, Train Acc: 0.3636, Test Acc: 0.4091
# Epoch: 005, Loss: 2.7534, Train Acc: 0.4091, Test Acc: 0.4091
# Epoch: 006, Loss: 2.7615, Train Acc: 0.3333, Test Acc: 0.3636
# Epoch: 007, Loss: 3.1282, Train Acc: 0.3788, Test Acc: 0.4091
# Epoch: 008, Loss: 2.1028, Train Acc: 0.3939, Test Acc: 0.4091
# Epoch: 009, Loss: 2.0689, Train Acc: 0.3788, Test Acc: 0.4091
# Epoch: 010, Loss: 1.3935, Train Acc: 0.3636, Test Acc: 0.4091
# Epoch: 011, Loss: 1.8381, Train Acc: 0.3636, Test Acc: 0.4091
# Epoch: 012, Loss: 1.6750, Train Acc: 0.3636, Test Acc: 0.4091
# Epoch: 013, Loss: 1.8585, Train Acc: 0.3636, Test Acc: 0.4318
# Epoch: 014, Loss: 1.2941, Train Acc: 0.3788, Test Acc: 0.4091
# Epoch: 015, Loss: 1.6335, Train Acc: 0.3788, Test Acc: 0.4091
# Epoch: 016, Loss: 1.6977, Train Acc: 0.3788, Test Acc: 0.4091
# Epoch: 017, Loss: 2.0905, Train Acc: 0.3788, Test Acc: 0.4318
# Epoch: 018, Loss: 1.9765, Train Acc: 0.3939, Test Acc: 0.4318
# Epoch: 019, Loss: 1.7150, Train Acc: 0.4091, Test Acc: 0.4545
# Epoch: 020, Loss: 1.7098, Train Acc: 0.4091, Test Acc: 0.4545
# Epoch: 021, Loss: 1.5449, Train Acc: 0.4091, Test Acc: 0.4545
# Epoch: 022, Loss: 1.8442, Train Acc: 0.4242, Test Acc: 0.4545
# Epoch: 023, Loss: 1.5218, Train Acc: 0.4242, Test Acc: 0.4545
# Epoch: 024, Loss: 1.5892, Train Acc: 0.4242, Test Acc: 0.4545
# Epoch: 025, Loss: 1.5473, Train Acc: 0.4545, Test Acc: 0.4545
# Epoch: 026, Loss: 1.0412, Train Acc: 0.4545, Test Acc: 0.4545
# Epoch: 027, Loss: 1.6625, Train Acc: 0.4545, Test Acc: 0.4545
# Epoch: 028, Loss: 1.5487, Train Acc: 0.4848, Test Acc: 0.4773
# Epoch: 029, Loss: 1.5186, Train Acc: 0.5152, Test Acc: 0.5000
# Epoch: 030, Loss: 1.2322, Train Acc: 0.5606, Test Acc: 0.5000
# Epoch: 031, Loss: 1.3259, Train Acc: 0.5758, Test Acc: 0.4545
# Epoch: 032, Loss: 1.6303, Train Acc: 0.4697, Test Acc: 0.5000
# Epoch: 033, Loss: 1.4057, Train Acc: 0.4545, Test Acc: 0.4773
# Epoch: 034, Loss: 1.4808, Train Acc: 0.5152, Test Acc: 0.4773
# Epoch: 035, Loss: 1.3934, Train Acc: 0.5303, Test Acc: 0.5000
# Epoch: 036, Loss: 1.1237, Train Acc: 0.5455, Test Acc: 0.5000
# Epoch: 037, Loss: 1.6447, Train Acc: 0.5152, Test Acc: 0.5000
# Epoch: 038, Loss: 1.6149, Train Acc: 0.5152, Test Acc: 0.4545
# Epoch: 039, Loss: 1.1133, Train Acc: 0.5152, Test Acc: 0.4545
# Epoch: 040, Loss: 0.9973, Train Acc: 0.5152, Test Acc: 0.4773
# Epoch: 041, Loss: 0.8450, Train Acc: 0.5303, Test Acc: 0.4773
# Epoch: 042, Loss: 1.2464, Train Acc: 0.5152, Test Acc: 0.4545
# Epoch: 043, Loss: 2.0349, Train Acc: 0.5152, Test Acc: 0.5000
# Epoch: 044, Loss: 1.4608, Train Acc: 0.5303, Test Acc: 0.5227
# Epoch: 045, Loss: 0.7697, Train Acc: 0.5152, Test Acc: 0.4773
# Epoch: 046, Loss: 1.5600, Train Acc: 0.5152, Test Acc: 0.4773
# Epoch: 047, Loss: 2.2935, Train Acc: 0.5152, Test Acc: 0.5000
# Epoch: 048, Loss: 1.0942, Train Acc: 0.5758, Test Acc: 0.5227
# Epoch: 049, Loss: 1.4770, Train Acc: 0.5606, Test Acc: 0.5000
# Epoch: 050, Loss: 1.1214, Train Acc: 0.5455, Test Acc: 0.5000
# Epoch: 051, Loss: 1.5449, Train Acc: 0.5152, Test Acc: 0.5000
# Epoch: 052, Loss: 1.8430, Train Acc: 0.5303, Test Acc: 0.5000
# Epoch: 053, Loss: 0.5852, Train Acc: 0.5455, Test Acc: 0.5000
# Epoch: 054, Loss: 1.4472, Train Acc: 0.5455, Test Acc: 0.4773
# Epoch: 055, Loss: 1.3121, Train Acc: 0.5152, Test Acc: 0.4318
# Epoch: 056, Loss: 0.9469, Train Acc: 0.5606, Test Acc: 0.4091
# Epoch: 057, Loss: 0.9806, Train Acc: 0.5455, Test Acc: 0.4773
# Epoch: 058, Loss: 1.1850, Train Acc: 0.5455, Test Acc: 0.5000
# Epoch: 059, Loss: 0.3848, Train Acc: 0.5303, Test Acc: 0.5000
# Epoch: 060, Loss: 0.8846, Train Acc: 0.5303, Test Acc: 0.5000
# Epoch: 061, Loss: 0.7266, Train Acc: 0.5152, Test Acc: 0.5000
# Epoch: 062, Loss: 0.7705, Train Acc: 0.5152, Test Acc: 0.5000
# Epoch: 063, Loss: 1.2317, Train Acc: 0.5455, Test Acc: 0.5227
# Epoch: 064, Loss: 0.5894, Train Acc: 0.6061, Test Acc: 0.5227
# Epoch: 065, Loss: 1.8185, Train Acc: 0.5758, Test Acc: 0.5455
# Epoch: 066, Loss: 0.6439, Train Acc: 0.5909, Test Acc: 0.5000
# Epoch: 067, Loss: 0.9342, Train Acc: 0.5758, Test Acc: 0.4773
# Epoch: 068, Loss: 1.4402, Train Acc: 0.6061, Test Acc: 0.5000
# Epoch: 069, Loss: 0.9451, Train Acc: 0.6818, Test Acc: 0.5227
# Epoch: 070, Loss: 1.1853, Train Acc: 0.6364, Test Acc: 0.5227
# Epoch: 071, Loss: 0.7754, Train Acc: 0.6515, Test Acc: 0.5455
# Epoch: 072, Loss: 0.9231, Train Acc: 0.6364, Test Acc: 0.5455
# Epoch: 073, Loss: 1.0003, Train Acc: 0.6212, Test Acc: 0.5000
# Epoch: 074, Loss: 1.1601, Train Acc: 0.6061, Test Acc: 0.5000
# Epoch: 075, Loss: 0.9166, Train Acc: 0.6212, Test Acc: 0.4545
# Epoch: 076, Loss: 1.0699, Train Acc: 0.6061, Test Acc: 0.4318
# Epoch: 077, Loss: 0.9118, Train Acc: 0.6364, Test Acc: 0.4091
# Epoch: 078, Loss: 0.9823, Train Acc: 0.6364, Test Acc: 0.5227
# Epoch: 079, Loss: 1.1024, Train Acc: 0.6970, Test Acc: 0.5455
# Epoch: 080, Loss: 1.3134, Train Acc: 0.7121, Test Acc: 0.5455
# Epoch: 081, Loss: 0.9369, Train Acc: 0.6667, Test Acc: 0.5455
# Epoch: 082, Loss: 1.3841, Train Acc: 0.6970, Test Acc: 0.5909
# Epoch: 083, Loss: 0.7225, Train Acc: 0.6970, Test Acc: 0.5909
# Epoch: 084, Loss: 1.2547, Train Acc: 0.6364, Test Acc: 0.5682
# Epoch: 085, Loss: 2.2817, Train Acc: 0.6061, Test Acc: 0.5000
# Epoch: 086, Loss: 1.3856, Train Acc: 0.5909, Test Acc: 0.5000
# Epoch: 087, Loss: 1.0249, Train Acc: 0.5606, Test Acc: 0.5000
# Epoch: 088, Loss: 0.7149, Train Acc: 0.5606, Test Acc: 0.5000
# Epoch: 089, Loss: 1.1676, Train Acc: 0.5758, Test Acc: 0.5455
# Epoch: 090, Loss: 0.8345, Train Acc: 0.5909, Test Acc: 0.5227
# Epoch: 091, Loss: 0.6341, Train Acc: 0.5909, Test Acc: 0.5227
# Epoch: 092, Loss: 1.8068, Train Acc: 0.5758, Test Acc: 0.5227
# Epoch: 093, Loss: 1.3670, Train Acc: 0.5758, Test Acc: 0.5227
# Epoch: 094, Loss: 0.7139, Train Acc: 0.5909, Test Acc: 0.5227
# Epoch: 095, Loss: 0.2388, Train Acc: 0.6061, Test Acc: 0.5227
# Epoch: 096, Loss: 0.4808, Train Acc: 0.6061, Test Acc: 0.5227
# Epoch: 097, Loss: 1.0240, Train Acc: 0.6061, Test Acc: 0.5455
# Epoch: 098, Loss: 1.3953, Train Acc: 0.6212, Test Acc: 0.5455
# Epoch: 099, Loss: 1.1576, Train Acc: 0.6364, Test Acc: 0.5682
# Epoch: 100, Loss: 1.0432, Train Acc: 0.6818, Test Acc: 0.5455
# Epoch: 101, Loss: 0.9800, Train Acc: 0.5758, Test Acc: 0.4545
# Epoch: 102, Loss: 1.3638, Train Acc: 0.6061, Test Acc: 0.5455
# Epoch: 103, Loss: 0.9465, Train Acc: 0.6364, Test Acc: 0.5227
# Epoch: 104, Loss: 0.8961, Train Acc: 0.6667, Test Acc: 0.5909
# Epoch: 105, Loss: 0.8376, Train Acc: 0.6970, Test Acc: 0.5909
# Epoch: 106, Loss: 1.3104, Train Acc: 0.6061, Test Acc: 0.5909
# Epoch: 107, Loss: 0.5697, Train Acc: 0.5606, Test Acc: 0.5227
# Epoch: 108, Loss: 0.9918, Train Acc: 0.5455, Test Acc: 0.5455
# Epoch: 109, Loss: 1.3188, Train Acc: 0.5758, Test Acc: 0.5682
# Epoch: 110, Loss: 1.1536, Train Acc: 0.6061, Test Acc: 0.5682
# Epoch: 111, Loss: 0.7777, Train Acc: 0.6364, Test Acc: 0.5682
# Epoch: 112, Loss: 1.5241, Train Acc: 0.6515, Test Acc: 0.5909
# Epoch: 113, Loss: 0.5342, Train Acc: 0.6667, Test Acc: 0.5909
# Epoch: 114, Loss: 1.1165, Train Acc: 0.6667, Test Acc: 0.5909
# Epoch: 115, Loss: 0.7664, Train Acc: 0.6667, Test Acc: 0.5909
# Epoch: 116, Loss: 0.3523, Train Acc: 0.6818, Test Acc: 0.5909
# Epoch: 117, Loss: 0.5139, Train Acc: 0.6818, Test Acc: 0.5909
# Epoch: 118, Loss: 0.4916, Train Acc: 0.6818, Test Acc: 0.6136
# Epoch: 119, Loss: 0.4379, Train Acc: 0.7121, Test Acc: 0.5909
# Epoch: 120, Loss: 0.6801, Train Acc: 0.7727, Test Acc: 0.5909
# Epoch: 121, Loss: 0.5283, Train Acc: 0.7576, Test Acc: 0.6136
# Epoch: 122, Loss: 1.5935, Train Acc: 0.7576, Test Acc: 0.6136
# Epoch: 123, Loss: 0.6562, Train Acc: 0.7424, Test Acc: 0.6136
# Epoch: 124, Loss: 0.7307, Train Acc: 0.7273, Test Acc: 0.5909
# Epoch: 125, Loss: 0.2473, Train Acc: 0.7273, Test Acc: 0.5909
# Epoch: 126, Loss: 1.0457, Train Acc: 0.6970, Test Acc: 0.5682
# Epoch: 127, Loss: 0.4653, Train Acc: 0.6970, Test Acc: 0.5682
# Epoch: 128, Loss: 1.0908, Train Acc: 0.6970, Test Acc: 0.5682
# Epoch: 129, Loss: 0.3022, Train Acc: 0.6970, Test Acc: 0.5682
# Epoch: 130, Loss: 1.1382, Train Acc: 0.7121, Test Acc: 0.5909
# Epoch: 131, Loss: 1.1808, Train Acc: 0.8030, Test Acc: 0.6591
# Epoch: 132, Loss: 0.3939, Train Acc: 0.7273, Test Acc: 0.6136
# Epoch: 133, Loss: 0.8520, Train Acc: 0.6667, Test Acc: 0.5000
# Epoch: 134, Loss: 0.6017, Train Acc: 0.6818, Test Acc: 0.5227
# Epoch: 135, Loss: 1.0467, Train Acc: 0.7424, Test Acc: 0.6364
# Epoch: 136, Loss: 0.5377, Train Acc: 0.7121, Test Acc: 0.6364
# Epoch: 137, Loss: 0.6287, Train Acc: 0.6818, Test Acc: 0.5909
# Epoch: 138, Loss: 0.8788, Train Acc: 0.7273, Test Acc: 0.6364
# Epoch: 139, Loss: 0.3598, Train Acc: 0.7879, Test Acc: 0.6364
# Epoch: 140, Loss: 0.3660, Train Acc: 0.7727, Test Acc: 0.6364
# Epoch: 141, Loss: 0.4208, Train Acc: 0.7424, Test Acc: 0.5455
# Epoch: 142, Loss: 1.0239, Train Acc: 0.6970, Test Acc: 0.5455
# Epoch: 143, Loss: 0.6268, Train Acc: 0.6970, Test Acc: 0.5455
# Epoch: 144, Loss: 0.7896, Train Acc: 0.7576, Test Acc: 0.6364
# Epoch: 145, Loss: 0.7887, Train Acc: 0.7727, Test Acc: 0.6364
# Epoch: 146, Loss: 0.6669, Train Acc: 0.7576, Test Acc: 0.6136
# Epoch: 147, Loss: 0.7687, Train Acc: 0.7273, Test Acc: 0.6364
# Epoch: 148, Loss: 0.6013, Train Acc: 0.7273, Test Acc: 0.6364
# Epoch: 149, Loss: 0.4742, Train Acc: 0.7576, Test Acc: 0.6364
# Epoch: 150, Loss: 0.7565, Train Acc: 0.7727, Test Acc: 0.5909
# Epoch: 151, Loss: 0.8986, Train Acc: 0.6667, Test Acc: 0.5000
# Epoch: 152, Loss: 1.9747, Train Acc: 0.8333, Test Acc: 0.6136
# Epoch: 153, Loss: 0.5177, Train Acc: 0.7727, Test Acc: 0.6591
# Epoch: 154, Loss: 0.4030, Train Acc: 0.7273, Test Acc: 0.6364
# Epoch: 155, Loss: 1.6213, Train Acc: 0.7576, Test Acc: 0.6818
# Epoch: 156, Loss: 0.6215, Train Acc: 0.7273, Test Acc: 0.6591
# Epoch: 157, Loss: 0.5416, Train Acc: 0.7727, Test Acc: 0.6818
# Epoch: 158, Loss: 0.4915, Train Acc: 0.7576, Test Acc: 0.6591
# Epoch: 159, Loss: 0.4486, Train Acc: 0.7576, Test Acc: 0.6364
# Epoch: 160, Loss: 0.2533, Train Acc: 0.7424, Test Acc: 0.6364
# Epoch: 161, Loss: 0.4787, Train Acc: 0.7121, Test Acc: 0.6364
# Epoch: 162, Loss: 0.4359, Train Acc: 0.7576, Test Acc: 0.6136
# Epoch: 163, Loss: 0.8524, Train Acc: 0.7879, Test Acc: 0.6364
# Epoch: 164, Loss: 0.0357, Train Acc: 0.7727, Test Acc: 0.6591
# Epoch: 165, Loss: 0.5659, Train Acc: 0.7727, Test Acc: 0.6818
# Epoch: 166, Loss: 1.7463, Train Acc: 0.8333, Test Acc: 0.6364
# Epoch: 167, Loss: 0.2687, Train Acc: 0.7879, Test Acc: 0.6364
# Epoch: 168, Loss: 0.7762, Train Acc: 0.8030, Test Acc: 0.6136
# Epoch: 169, Loss: 0.6669, Train Acc: 0.8182, Test Acc: 0.6591
# Epoch: 170, Loss: 0.9203, Train Acc: 0.7576, Test Acc: 0.5909
# Epoch: 171, Loss: 1.4296, Train Acc: 0.7727, Test Acc: 0.6364
# Epoch: 172, Loss: 1.1484, Train Acc: 0.7879, Test Acc: 0.5455
# Epoch: 173, Loss: 0.5765, Train Acc: 0.7576, Test Acc: 0.5455
# Epoch: 174, Loss: 0.5429, Train Acc: 0.7121, Test Acc: 0.5909
# Epoch: 175, Loss: 0.5274, Train Acc: 0.6667, Test Acc: 0.5455
# Epoch: 176, Loss: 1.3250, Train Acc: 0.6364, Test Acc: 0.5227
# Epoch: 177, Loss: 1.3145, Train Acc: 0.6818, Test Acc: 0.5682
# Epoch: 178, Loss: 1.4160, Train Acc: 0.6818, Test Acc: 0.5909
# Epoch: 179, Loss: 0.3049, Train Acc: 0.7121, Test Acc: 0.6136
# Epoch: 180, Loss: 0.5948, Train Acc: 0.7121, Test Acc: 0.5909
# Epoch: 181, Loss: 0.3858, Train Acc: 0.6970, Test Acc: 0.5909
# Epoch: 182, Loss: 0.5866, Train Acc: 0.6970, Test Acc: 0.5909
# Epoch: 183, Loss: 0.6040, Train Acc: 0.6970, Test Acc: 0.5227
# Epoch: 184, Loss: 0.6843, Train Acc: 0.7121, Test Acc: 0.5000
# Epoch: 185, Loss: 0.7371, Train Acc: 0.7121, Test Acc: 0.5909
# Epoch: 186, Loss: 0.8841, Train Acc: 0.7576, Test Acc: 0.6364
# Epoch: 187, Loss: 0.7874, Train Acc: 0.7879, Test Acc: 0.6136
# Epoch: 188, Loss: 0.5653, Train Acc: 0.8333, Test Acc: 0.5909
# Epoch: 189, Loss: 0.3337, Train Acc: 0.8333, Test Acc: 0.5909
# Epoch: 190, Loss: 0.2812, Train Acc: 0.8485, Test Acc: 0.5909
# Epoch: 191, Loss: 0.7251, Train Acc: 0.8485, Test Acc: 0.6364
# Epoch: 192, Loss: 0.5335, Train Acc: 0.8485, Test Acc: 0.6364
# Epoch: 193, Loss: 0.4162, Train Acc: 0.8333, Test Acc: 0.6591
# Epoch: 194, Loss: 0.3608, Train Acc: 0.8636, Test Acc: 0.6591
# Epoch: 195, Loss: 1.0103, Train Acc: 0.8485, Test Acc: 0.6591
# Epoch: 196, Loss: 0.7138, Train Acc: 0.8333, Test Acc: 0.6818
# Epoch: 197, Loss: 0.4303, Train Acc: 0.8333, Test Acc: 0.6591
# Epoch: 198, Loss: 1.1395, Train Acc: 0.8333, Test Acc: 0.6818
# Epoch: 199, Loss: 0.4986, Train Acc: 0.7879, Test Acc: 0.6818
# Epoch: 200, Loss: 0.5257, Train Acc: 0.7727, Test Acc: 0.6818
