# %%
import os.path as osp

import torch
import torch.nn.functional as F

from torch_geometric.loader import DataLoader
from torch_geometric.nn import GATConv, SAGEConv, NNConv, GCNConv
import matplotlib.pyplot as plt

# %%
from torch_geometric.datasets import Planetoid
from sklearn.manifold import TSNE
from torch_geometric.nn import Node2Vec

dataset = Planetoid('./data/Planetoid', name='Cora')
data = dataset[0]
data
# Out:
# Data(x=[2708, 1433], edge_index=[2, 10556], y=[2708], train_mask=[2708], val_mask=[2708], test_mask=[2708])

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'
model = Node2Vec(data.edge_index, embedding_dim=64, walk_length=20,
                 context_size=10, walks_per_node=10,
                 num_negative_samples=1, p=1, q=1, sparse=True).to(device)

num_workers = 0
loader = model.loader(batch_size=128, shuffle=True, num_workers=num_workers)
optimizer = torch.optim.SparseAdam(list(model.parameters()), lr=0.01)

def train():
    model.train()
    total_loss = 0
    for pos_rw, neg_rw in loader:
        optimizer.zero_grad()
        loss = model.loss(pos_rw.to(device), neg_rw.to(device))
        loss.backward()
        optimizer.step()
        total_loss += loss.item()
    return total_loss / len(loader)

@torch.no_grad()
def test():
    model.eval()
    z = model()
    acc = model.test(z[data.train_mask], data.y[data.train_mask],
                     z[data.test_mask], data.y[data.test_mask],
                     max_iter=150)
    return acc

acc_values = []
loss_values = []
for epoch in range(1, 101):
    loss = train()
    acc = test()
    loss_values.append(loss)
    acc_values.append(acc)
    print(f'Epoch: {epoch:02d}, Loss: {loss:.4f}, Acc: {acc:.4f}')
    

plt.plot(loss_values, 'r',)
plt.show()
plt.plot(acc_values, 'b',)
plt.show()

@torch.no_grad()
def plot_points(colors):
    model.eval()
    z = model(torch.arange(data.num_nodes, device=device))
    z = TSNE(n_components=2).fit_transform(z.cpu().numpy())
    y = data.y.cpu().numpy()

    plt.figure(figsize=(8, 8))
    for i in range(dataset.num_classes):
        plt.scatter(z[y == i, 0], z[y == i, 1], s=20, color=colors[i])
    plt.axis('off')
    plt.show()

colors = [
    '#ffc0cb', '#bada55', '#008080', '#420420', '#7fe5f0', '#065535',
    '#ffd700'
]
plot_points(colors)
# Out:
# Epoch: 01, Loss: 5.5210, Acc: 0.1590
# Epoch: 02, Loss: 4.0318, Acc: 0.1780
# Epoch: 03, Loss: 3.1692, Acc: 0.2100
# Epoch: 04, Loss: 2.5948, Acc: 0.2390
# Epoch: 05, Loss: 2.1857, Acc: 0.2710
# Epoch: 06, Loss: 1.8775, Acc: 0.3040
# Epoch: 07, Loss: 1.6472, Acc: 0.3500
# Epoch: 08, Loss: 1.4708, Acc: 0.3940
# Epoch: 09, Loss: 1.3317, Acc: 0.4410
# Epoch: 10, Loss: 1.2293, Acc: 0.4740
# Epoch: 11, Loss: 1.1537, Acc: 0.5040
# Epoch: 12, Loss: 1.0945, Acc: 0.5260
# Epoch: 13, Loss: 1.0478, Acc: 0.5480
# Epoch: 14, Loss: 1.0135, Acc: 0.5740
# Epoch: 61, Loss: 0.8307, Acc: 0.7050
# Epoch: 62, Loss: 0.8311, Acc: 0.6960
# Epoch: 63, Loss: 0.8310, Acc: 0.7120
# Epoch: 64, Loss: 0.8299, Acc: 0.7160
# Epoch: 65, Loss: 0.8305, Acc: 0.7220
# Epoch: 66, Loss: 0.8305, Acc: 0.7140
# Epoch: 67, Loss: 0.8309, Acc: 0.7140
# Epoch: 68, Loss: 0.8294, Acc: 0.7160
# Epoch: 69, Loss: 0.8300, Acc: 0.7100
# Epoch: 70, Loss: 0.8302, Acc: 0.7130
# Epoch: 71, Loss: 0.8301, Acc: 0.7100
# Epoch: 72, Loss: 0.8302, Acc: 0.7120
# Epoch: 73, Loss: 0.8301, Acc: 0.7140
# Epoch: 74, Loss: 0.8295, Acc: 0.7150
# Epoch: 75, Loss: 0.8287, Acc: 0.7180
# Epoch: 76, Loss: 0.8302, Acc: 0.7140
# Epoch: 77, Loss: 0.8294, Acc: 0.7120
# Epoch: 78, Loss: 0.8293, Acc: 0.7170
# Epoch: 79, Loss: 0.8287, Acc: 0.7160
# Epoch: 80, Loss: 0.8283, Acc: 0.7070
# Epoch: 81, Loss: 0.8290, Acc: 0.7120
# Epoch: 82, Loss: 0.8281, Acc: 0.7170
# Epoch: 83, Loss: 0.8286, Acc: 0.7090
# Epoch: 84, Loss: 0.8275, Acc: 0.7020
# Epoch: 85, Loss: 0.8287, Acc: 0.7030
# Epoch: 86, Loss: 0.8286, Acc: 0.7060
# Epoch: 87, Loss: 0.8286, Acc: 0.7060
# Epoch: 88, Loss: 0.8275, Acc: 0.6980
# Epoch: 89, Loss: 0.8288, Acc: 0.7000
# Epoch: 90, Loss: 0.8286, Acc: 0.7090
# Epoch: 91, Loss: 0.8268, Acc: 0.7120
# Epoch: 92, Loss: 0.8283, Acc: 0.7030
# Epoch: 93, Loss: 0.8277, Acc: 0.7120
# Epoch: 94, Loss: 0.8285, Acc: 0.7130
# Epoch: 95, Loss: 0.8272, Acc: 0.7190
# Epoch: 96, Loss: 0.8281, Acc: 0.7130
# Epoch: 97, Loss: 0.8276, Acc: 0.7090
# Epoch: 98, Loss: 0.8274, Acc: 0.7130
# Epoch: 99, Loss: 0.8269, Acc: 0.7060
# Epoch: 100, Loss: 0.8281, Acc: 0.7100
# C:\Users\alber\anaconda3\envs\pyg_env\lib\site-packages\sklearn\manifold\_t_sne.py:795: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# C:\Users\alber\anaconda3\envs\pyg_env\lib\site-packages\sklearn\manifold\_t_sne.py:805: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(

# %%
plt.plot(acc_values, 'b',)
plt.savefig('node2vec_acc_cora.png')
plt.show()

plt.plot(loss_values, 'r')
plt.savefig('node2vec_loss_cora.png')
plt.show()
