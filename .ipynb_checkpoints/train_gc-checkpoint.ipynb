# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
# %run dataset_gc.ipynb
# Out:
# DATASET LOADED
# EnterpriseModelDatasetGC(110)
# Processing...
# Done!

# %%
torch.manual_seed(42)
dataset = dataset_gc.shuffle()

print()
print(f'Dataset: {dataset}:')
print('====================')
print(f'Number of graphs: {len(dataset)}')
print(f'Number of features: {dataset.num_features}')
print(f'Number of classes: {dataset.num_classes}')
dataset[0]
# Out:
# Dataset: EnterpriseModelDatasetGC(110):
# ====================
# Number of graphs: 110
# Number of features: 1
# Number of classes: 9
# Data(x=[26, 1], edge_index=[2, 25], edge_attr=[25, 1], y=7)

# %%
torch.manual_seed(42)

balanced = False

while not balanced:
    dataset = dataset.shuffle()
    train_dataset = dataset[:int(len(dataset) * 0.6)]
    test_dataset = dataset[int(len(dataset) * 0.6):]
    
    train_ys = [0 for i in range(0,len(model_classes))]
    test_ys =[0 for i in range(0,len(model_classes))]

    for train_g in train_dataset:
        y = train_g.y
        train_ys[y] += 1


    for test_g in test_dataset:
        y = test_g.y
        test_ys[y] += 1
        
    if(0 not in train_ys and 1 not in train_ys and 0 not in test_ys and 1 not in test_ys):
        balanced = True


print(train_ys)
print(test_ys)
print("Datasets balanced!")

print(f'Number of graphs total: {len(dataset)}')
print(f'Number of training graphs: {len(train_dataset)}')
print(f'Number of test graphs: {len(test_dataset)}')
# Out:
# [5, 4, 6, 7, 2, 2, 8, 25, 7]
# [2, 3, 4, 5, 4, 2, 2, 18, 4]
# Datasets balanced!
# Number of graphs total: 110
# Number of training graphs: 66
# Number of test graphs: 44

# %%
from torch_geometric.loader import DataLoader

NUM_GRAPHS_PER_BATCH = 32
NUM_HIDDEN_CHANNELS = 32

train_loader = DataLoader(train_dataset, batch_size=NUM_GRAPHS_PER_BATCH, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=NUM_GRAPHS_PER_BATCH, shuffle=False)

# %%
from torch.nn import Linear
import torch.nn.functional as F
from torch_geometric.nn import SAGEConv
from torch_geometric.nn import global_mean_pool


class Net(torch.nn.Module):
    def __init__(self, hidden_channels):
        super(Net, self).__init__()
        torch.manual_seed(42)
        self.conv1 = SAGEConv(dataset.num_node_features, 2 * hidden_channels)
        self.conv2 = SAGEConv(2 * hidden_channels, 4 *  hidden_channels)
        self.conv3 = SAGEConv(4 * hidden_channels, 2 * hidden_channels)
        self.lin1 = Linear(2 * hidden_channels, hidden_channels)
        self.lin2 = Linear(hidden_channels, dataset.num_classes)

    def forward(self, x, edge_index, batch):
        x = self.conv1(x, edge_index)
        x = x.relu()
        x = self.conv2(x, edge_index)
        x = x.relu()
        x = self.conv3(x, edge_index)

        x = global_mean_pool(x, batch)  # [batch_size, hidden_channels]

        x = F.dropout(x, p=0.5, training=self.training)
        x = self.lin1(x)
        x = self.lin2(x)
        return x

# %%
model = Net(hidden_channels=NUM_HIDDEN_CHANNELS)
print(model)
print("Number of parameters: ", sum(p.numel() for p in model.parameters()))

optimizer = torch.optim.Adam(model.parameters(), lr=0.005)
criterion = torch.nn.CrossEntropyLoss()

def train():
    model.train()

    for data in train_loader:
        out = model(data.x, data.edge_index, data.batch)
        loss = criterion(out, data.y)
        loss.backward()
        optimizer.step()
        optimizer.zero_grad()
        return loss

def test(loader):
    model.eval()
    correct = 0
    for data in loader:
        out = model(data.x, data.edge_index, data.batch)  
        pred = out.argmax(dim=1)
        correct += int((pred == data.y).sum())
    return correct / len(loader.dataset)

loss_values = []
train_acc_values = []
acc_values = []

for epoch in range(1, 201):
    loss = train()
    train_acc = test(train_loader)
    test_acc = test(test_loader)
        
    loss_values.append(loss)
    acc_values.append(test_acc)
    train_acc_values.append(train_acc)
    print(f'Epoch: {epoch:03d}, Loss: {loss:.4f}, Train Acc: {train_acc:.4f}, Test Acc: {test_acc:.4f}')
    if(test_acc > 0.81):
        break

plt.plot(acc_values, 'b', train_acc_values, 'g')
plt.savefig('acc_gc.png')
plt.show()

losses = [loss_values[i].item() for i in range(0, len(loss_values))]
plt.plot(losses, 'r')
plt.savefig('loss_gc.png')
plt.show()
# Out:
# Net(
#   (conv1): SAGEConv(1, 64)
#   (conv2): SAGEConv(64, 128)
#   (conv3): SAGEConv(128, 64)
#   (lin1): Linear(in_features=64, out_features=32, bias=True)
#   (lin2): Linear(in_features=32, out_features=9, bias=True)
# )
# Number of parameters:  35529
# Epoch: 001, Loss: 2.7560, Train Acc: 0.3788, Test Acc: 0.4091
# Epoch: 002, Loss: 3.9726, Train Acc: 0.4091, Test Acc: 0.4318
# Epoch: 003, Loss: 2.6511, Train Acc: 0.4242, Test Acc: 0.3636
# Epoch: 004, Loss: 2.0475, Train Acc: 0.4697, Test Acc: 0.3864
# Epoch: 005, Loss: 2.0320, Train Acc: 0.4848, Test Acc: 0.3864
# Epoch: 006, Loss: 1.9669, Train Acc: 0.4697, Test Acc: 0.3864
# Epoch: 007, Loss: 1.9350, Train Acc: 0.4697, Test Acc: 0.3864
# Epoch: 008, Loss: 1.8778, Train Acc: 0.4394, Test Acc: 0.4091
# Epoch: 009, Loss: 1.8391, Train Acc: 0.4394, Test Acc: 0.4318
# Epoch: 010, Loss: 1.6844, Train Acc: 0.4242, Test Acc: 0.4091
# Epoch: 011, Loss: 1.6181, Train Acc: 0.4242, Test Acc: 0.4091
# Epoch: 012, Loss: 1.7541, Train Acc: 0.4242, Test Acc: 0.4091
# Epoch: 013, Loss: 1.6186, Train Acc: 0.4242, Test Acc: 0.3864
# Epoch: 014, Loss: 1.4158, Train Acc: 0.4394, Test Acc: 0.3864
# Epoch: 015, Loss: 1.6501, Train Acc: 0.5152, Test Acc: 0.4545
# Epoch: 016, Loss: 1.5154, Train Acc: 0.5152, Test Acc: 0.4773
# Epoch: 017, Loss: 1.4088, Train Acc: 0.5000, Test Acc: 0.4773
# Epoch: 018, Loss: 1.6117, Train Acc: 0.5152, Test Acc: 0.4318
# Epoch: 019, Loss: 1.7175, Train Acc: 0.4545, Test Acc: 0.3864
# Epoch: 020, Loss: 1.5713, Train Acc: 0.4848, Test Acc: 0.4091
# Epoch: 021, Loss: 1.6003, Train Acc: 0.5152, Test Acc: 0.4091
# Epoch: 022, Loss: 1.4418, Train Acc: 0.5303, Test Acc: 0.4318
# Epoch: 023, Loss: 1.3311, Train Acc: 0.5758, Test Acc: 0.4545
# Epoch: 024, Loss: 1.3733, Train Acc: 0.5303, Test Acc: 0.4545
# Epoch: 025, Loss: 1.6798, Train Acc: 0.5000, Test Acc: 0.4318
# Epoch: 026, Loss: 1.3440, Train Acc: 0.5000, Test Acc: 0.4091
# Epoch: 027, Loss: 1.5706, Train Acc: 0.4848, Test Acc: 0.4091
# Epoch: 028, Loss: 1.4873, Train Acc: 0.5000, Test Acc: 0.4091
# Epoch: 029, Loss: 1.2050, Train Acc: 0.5909, Test Acc: 0.4318
# Epoch: 030, Loss: 1.7588, Train Acc: 0.6212, Test Acc: 0.4545
# Epoch: 031, Loss: 1.6735, Train Acc: 0.6364, Test Acc: 0.4773
# Epoch: 032, Loss: 1.3897, Train Acc: 0.6515, Test Acc: 0.4545
# Epoch: 033, Loss: 1.2178, Train Acc: 0.6212, Test Acc: 0.4545
# Epoch: 034, Loss: 1.4573, Train Acc: 0.6212, Test Acc: 0.4318
# Epoch: 035, Loss: 1.2048, Train Acc: 0.6667, Test Acc: 0.5227
# Epoch: 036, Loss: 1.2445, Train Acc: 0.5909, Test Acc: 0.4773
# Epoch: 037, Loss: 1.2434, Train Acc: 0.5909, Test Acc: 0.4545
# Epoch: 038, Loss: 1.1792, Train Acc: 0.6212, Test Acc: 0.5000
# Epoch: 039, Loss: 1.2626, Train Acc: 0.6515, Test Acc: 0.5227
# Epoch: 040, Loss: 1.2028, Train Acc: 0.6515, Test Acc: 0.5227
# Epoch: 041, Loss: 1.2363, Train Acc: 0.6061, Test Acc: 0.5000
# Epoch: 042, Loss: 1.2751, Train Acc: 0.6212, Test Acc: 0.5000
# Epoch: 043, Loss: 1.1883, Train Acc: 0.6364, Test Acc: 0.4773
# Epoch: 044, Loss: 1.1624, Train Acc: 0.6061, Test Acc: 0.4773
# Epoch: 045, Loss: 1.1948, Train Acc: 0.5909, Test Acc: 0.4545
# Epoch: 046, Loss: 1.1040, Train Acc: 0.5909, Test Acc: 0.4545
# Epoch: 047, Loss: 1.2541, Train Acc: 0.6212, Test Acc: 0.4773
# Epoch: 048, Loss: 1.2167, Train Acc: 0.6364, Test Acc: 0.5000
# Epoch: 049, Loss: 1.1850, Train Acc: 0.6667, Test Acc: 0.5000
# Epoch: 050, Loss: 0.9748, Train Acc: 0.6515, Test Acc: 0.5000
# Epoch: 051, Loss: 0.9853, Train Acc: 0.6667, Test Acc: 0.5227
# Epoch: 052, Loss: 1.1452, Train Acc: 0.6515, Test Acc: 0.4773
# Epoch: 053, Loss: 0.9567, Train Acc: 0.6364, Test Acc: 0.4773
# Epoch: 054, Loss: 1.3724, Train Acc: 0.6515, Test Acc: 0.5227
# Epoch: 055, Loss: 0.8626, Train Acc: 0.6515, Test Acc: 0.4545
# Epoch: 056, Loss: 0.7464, Train Acc: 0.6364, Test Acc: 0.4773
# Epoch: 057, Loss: 1.0206, Train Acc: 0.6364, Test Acc: 0.4773
# Epoch: 058, Loss: 0.9974, Train Acc: 0.6515, Test Acc: 0.5000
# Epoch: 059, Loss: 1.1211, Train Acc: 0.6515, Test Acc: 0.5000
# Epoch: 060, Loss: 0.5962, Train Acc: 0.6364, Test Acc: 0.5000
# Epoch: 061, Loss: 0.8778, Train Acc: 0.6364, Test Acc: 0.5000
# Epoch: 062, Loss: 1.1704, Train Acc: 0.6818, Test Acc: 0.5227
# Epoch: 063, Loss: 0.6791, Train Acc: 0.6970, Test Acc: 0.5682
# Epoch: 064, Loss: 0.8020, Train Acc: 0.7576, Test Acc: 0.5455
# Epoch: 065, Loss: 0.9399, Train Acc: 0.6818, Test Acc: 0.5227
# Epoch: 066, Loss: 1.1859, Train Acc: 0.6515, Test Acc: 0.5000
# Epoch: 067, Loss: 0.8135, Train Acc: 0.6515, Test Acc: 0.5227
# Epoch: 068, Loss: 0.9823, Train Acc: 0.7121, Test Acc: 0.5682
# Epoch: 069, Loss: 0.8145, Train Acc: 0.7576, Test Acc: 0.5909
# Epoch: 070, Loss: 0.9210, Train Acc: 0.6667, Test Acc: 0.5227
# Epoch: 071, Loss: 0.8380, Train Acc: 0.7576, Test Acc: 0.5682
# Epoch: 072, Loss: 0.7573, Train Acc: 0.7424, Test Acc: 0.5455
# Epoch: 073, Loss: 0.7088, Train Acc: 0.7273, Test Acc: 0.5682
# Epoch: 074, Loss: 0.8007, Train Acc: 0.7576, Test Acc: 0.6136
# Epoch: 075, Loss: 0.5173, Train Acc: 0.7424, Test Acc: 0.5909
# Epoch: 076, Loss: 0.8648, Train Acc: 0.7273, Test Acc: 0.5682
# Epoch: 077, Loss: 0.7545, Train Acc: 0.7424, Test Acc: 0.5455
# Epoch: 078, Loss: 0.9468, Train Acc: 0.7273, Test Acc: 0.5227
# Epoch: 079, Loss: 0.7873, Train Acc: 0.7273, Test Acc: 0.5227
# Epoch: 080, Loss: 0.8649, Train Acc: 0.7727, Test Acc: 0.5455
# Epoch: 081, Loss: 0.7297, Train Acc: 0.8333, Test Acc: 0.6364
# Epoch: 082, Loss: 0.7954, Train Acc: 0.8030, Test Acc: 0.6136
# Epoch: 083, Loss: 0.6928, Train Acc: 0.7879, Test Acc: 0.5682
# Epoch: 084, Loss: 0.7189, Train Acc: 0.7424, Test Acc: 0.5682
# Epoch: 085, Loss: 1.1558, Train Acc: 0.7576, Test Acc: 0.5909
# Epoch: 086, Loss: 0.6837, Train Acc: 0.8030, Test Acc: 0.6136
# Epoch: 087, Loss: 0.7097, Train Acc: 0.8030, Test Acc: 0.6364
# Epoch: 088, Loss: 0.6851, Train Acc: 0.7576, Test Acc: 0.5682
# Epoch: 089, Loss: 0.6333, Train Acc: 0.8030, Test Acc: 0.6136
# Epoch: 090, Loss: 0.6317, Train Acc: 0.7879, Test Acc: 0.6364
# Epoch: 091, Loss: 0.6728, Train Acc: 0.7576, Test Acc: 0.5682
# Epoch: 092, Loss: 1.0477, Train Acc: 0.7576, Test Acc: 0.6136
# Epoch: 093, Loss: 0.6780, Train Acc: 0.7879, Test Acc: 0.6591
# Epoch: 094, Loss: 0.5990, Train Acc: 0.8182, Test Acc: 0.6136
# Epoch: 095, Loss: 0.5136, Train Acc: 0.8030, Test Acc: 0.6364
# Epoch: 096, Loss: 0.4645, Train Acc: 0.7576, Test Acc: 0.6136
# Epoch: 097, Loss: 0.9605, Train Acc: 0.8636, Test Acc: 0.7045
# Epoch: 098, Loss: 0.4743, Train Acc: 0.8333, Test Acc: 0.7045
# Epoch: 099, Loss: 0.6628, Train Acc: 0.8030, Test Acc: 0.7045
# Epoch: 100, Loss: 0.7633, Train Acc: 0.8030, Test Acc: 0.6591
# Epoch: 101, Loss: 0.6334, Train Acc: 0.8030, Test Acc: 0.5909
# Epoch: 102, Loss: 0.5761, Train Acc: 0.8333, Test Acc: 0.6136
# Epoch: 103, Loss: 0.6121, Train Acc: 0.8333, Test Acc: 0.5909
# Epoch: 104, Loss: 0.8038, Train Acc: 0.8485, Test Acc: 0.6364
# Epoch: 105, Loss: 0.3890, Train Acc: 0.8333, Test Acc: 0.6591
# Epoch: 106, Loss: 0.5740, Train Acc: 0.8333, Test Acc: 0.6818
# Epoch: 107, Loss: 0.5197, Train Acc: 0.8333, Test Acc: 0.6818
# Epoch: 108, Loss: 0.6315, Train Acc: 0.8030, Test Acc: 0.6591
# Epoch: 109, Loss: 0.5184, Train Acc: 0.8182, Test Acc: 0.6818
# Epoch: 110, Loss: 0.8192, Train Acc: 0.8788, Test Acc: 0.7273
# Epoch: 111, Loss: 0.4320, Train Acc: 0.8788, Test Acc: 0.7273
# Epoch: 112, Loss: 0.5533, Train Acc: 0.8485, Test Acc: 0.7500
# Epoch: 113, Loss: 0.3421, Train Acc: 0.8333, Test Acc: 0.7045
# Epoch: 114, Loss: 0.4716, Train Acc: 0.8485, Test Acc: 0.7273
# Epoch: 115, Loss: 0.6335, Train Acc: 0.8636, Test Acc: 0.7273
# Epoch: 116, Loss: 0.3460, Train Acc: 0.8939, Test Acc: 0.7500
# Epoch: 117, Loss: 0.5454, Train Acc: 0.8788, Test Acc: 0.7727
# Epoch: 118, Loss: 0.5346, Train Acc: 0.9242, Test Acc: 0.7727
# Epoch: 119, Loss: 0.5689, Train Acc: 0.9394, Test Acc: 0.7955
# Epoch: 120, Loss: 0.5627, Train Acc: 0.9242, Test Acc: 0.7955
# Epoch: 121, Loss: 0.3803, Train Acc: 0.9091, Test Acc: 0.7955
# Epoch: 122, Loss: 0.4170, Train Acc: 0.9091, Test Acc: 0.7727
# Epoch: 123, Loss: 0.3402, Train Acc: 0.9091, Test Acc: 0.7500
# Epoch: 124, Loss: 0.4714, Train Acc: 0.9091, Test Acc: 0.7045
# Epoch: 125, Loss: 0.4136, Train Acc: 0.8939, Test Acc: 0.6818
# Epoch: 126, Loss: 0.3055, Train Acc: 0.8939, Test Acc: 0.6818
# Epoch: 127, Loss: 0.3973, Train Acc: 0.9091, Test Acc: 0.7045
# Epoch: 128, Loss: 0.5404, Train Acc: 0.9091, Test Acc: 0.7273
# Epoch: 129, Loss: 0.3543, Train Acc: 0.9091, Test Acc: 0.7273
# Epoch: 130, Loss: 0.2494, Train Acc: 0.8939, Test Acc: 0.7500
# Epoch: 131, Loss: 0.4937, Train Acc: 0.8939, Test Acc: 0.7500
# Epoch: 132, Loss: 0.2665, Train Acc: 0.8939, Test Acc: 0.7727
# Epoch: 133, Loss: 0.3487, Train Acc: 0.8788, Test Acc: 0.7045
# Epoch: 134, Loss: 0.4321, Train Acc: 0.8939, Test Acc: 0.6818
# Epoch: 135, Loss: 0.2328, Train Acc: 0.8636, Test Acc: 0.7273
# Epoch: 136, Loss: 0.2766, Train Acc: 0.8636, Test Acc: 0.6818
# Epoch: 137, Loss: 0.4831, Train Acc: 0.8485, Test Acc: 0.7045
# Epoch: 138, Loss: 0.7497, Train Acc: 0.8788, Test Acc: 0.7500
# Epoch: 139, Loss: 0.4212, Train Acc: 0.9091, Test Acc: 0.7273
# Epoch: 140, Loss: 0.2285, Train Acc: 0.8485, Test Acc: 0.7045
# Epoch: 141, Loss: 0.7996, Train Acc: 0.8636, Test Acc: 0.7500
# Epoch: 142, Loss: 0.3931, Train Acc: 0.8788, Test Acc: 0.7273
# Epoch: 143, Loss: 0.2129, Train Acc: 0.8788, Test Acc: 0.7273
# Epoch: 144, Loss: 0.2875, Train Acc: 0.8939, Test Acc: 0.7500
# Epoch: 145, Loss: 0.3349, Train Acc: 0.9091, Test Acc: 0.7273
# Epoch: 146, Loss: 0.4970, Train Acc: 0.8939, Test Acc: 0.7500
# Epoch: 147, Loss: 0.4140, Train Acc: 0.8939, Test Acc: 0.7045
# Epoch: 148, Loss: 0.4055, Train Acc: 0.8788, Test Acc: 0.6818
# Epoch: 149, Loss: 0.5399, Train Acc: 0.8788, Test Acc: 0.7045
# Epoch: 150, Loss: 0.4195, Train Acc: 0.9242, Test Acc: 0.7500
# Epoch: 151, Loss: 0.2260, Train Acc: 0.8939, Test Acc: 0.7727
# Epoch: 152, Loss: 0.3407, Train Acc: 0.8939, Test Acc: 0.7727
# Epoch: 153, Loss: 0.4025, Train Acc: 0.8939, Test Acc: 0.7273
# Epoch: 154, Loss: 0.2090, Train Acc: 0.9091, Test Acc: 0.7273
# Epoch: 155, Loss: 0.5099, Train Acc: 0.9091, Test Acc: 0.7273
# Epoch: 156, Loss: 0.3544, Train Acc: 0.9091, Test Acc: 0.7273
# Epoch: 157, Loss: 0.2801, Train Acc: 0.9394, Test Acc: 0.7500
# Epoch: 158, Loss: 0.2744, Train Acc: 0.9545, Test Acc: 0.8182
