# %%
# Helper function for visualization.
# %matplotlib inline
import networkx as nx
import matplotlib.pyplot as plt

def visualize_graph(G, color):
    plt.figure(figsize=(7,7))
    plt.xticks([])
    plt.yticks([])
    nx.draw_networkx(G, pos=nx.spring_layout(G, seed=42), with_labels=False,
                     node_color=color, cmap="Set2")
    plt.show()


def visualize_embedding(h, color, epoch=None, loss=None):
    plt.figure(figsize=(7,7))
    plt.xticks([])
    plt.yticks([])
    h = h.detach().cpu().numpy()
    plt.scatter(h[:, 0], h[:, 1], s=140, c=color, cmap="Set2")
    if epoch is not None and loss is not None:
        plt.xlabel(f'Epoch: {epoch}, Loss: {loss.item():.4f}', fontsize=16)
    plt.show()

# %%
# %run dataset_gc.ipynb
# Out:
# DATASET LOADED
# EnterpriseModelDatasetGC(110)
# Processing...
# Done!

# %%
torch.manual_seed(42)
dataset = dataset_gc.shuffle()

print()
print(f'Dataset: {dataset}:')
print('====================')
print(f'Number of graphs: {len(dataset)}')
print(f'Number of features: {dataset.num_features}')
print(f'Number of classes: {dataset.num_classes}')

data = dataset[0]  # Get the first graph object.

print()
print(data)
print('=============================================================')

# Gather some statistics about the first graph.
print(f'Number of nodes: {data.num_nodes}')
print(f'Number of edges: {data.num_edges}')
print(f'Average node degree: {data.num_edges / data.num_nodes:.2f}')
print(f'Has isolated nodes: {data.has_isolated_nodes()}')
print(f'Has self-loops: {data.has_self_loops()}')
print(f'Is undirected: {data.is_undirected()}')

print()
print('=============================================================')

print(data.x[0])
print(data.edge_attr.shape)
print(data.y)
# Out:
# Dataset: EnterpriseModelDatasetGC(110):
# ====================
# Number of graphs: 110
# Number of features: 1
# Number of classes: 9
#
# Data(x=[26, 1], edge_index=[2, 25], edge_attr=[25, 1], y=[1])
# =============================================================
# Number of nodes: 26
# Number of edges: 25
# Average node degree: 0.96
# Has isolated nodes: False
# Has self-loops: False
# Is undirected: False
#
# =============================================================
# tensor([16.])
# torch.Size([25, 1])
# tensor([5])

# %%
torch.manual_seed(42)
dataset = dataset.shuffle()

train_dataset = dataset[:int(len(dataset) * 0.6)]
test_dataset = dataset[int(len(dataset) * 0.6):]

print(f'Number of graphs total: {len(dataset)}')
print(f'Number of training graphs: {len(train_dataset)}')
print(f'Number of test graphs: {len(test_dataset)}')
# Out:
# Number of graphs total: 110
# Number of training graphs: 66
# Number of test graphs: 44

# %%
from torch_geometric.loader import DataLoader

NUM_GRAPHS_PER_BATCH = 8
NUM_HIDDEN_CHANNELS = 32

train_loader = DataLoader(train_dataset, batch_size=NUM_GRAPHS_PER_BATCH, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=NUM_GRAPHS_PER_BATCH, shuffle=True)

#for step, data in enumerate(train_loader):
    #print(f'Step {step + 1}:')
    #print('=======')
    #print(f'Number of graphs in the current batch: {data.num_graphs}')
    #print(data)
    #print()

# %%
from torch.nn import Linear
import torch.nn.functional as F
from torch_geometric.nn import GCNConv, GraphConv, SAGEConv, GATConv
from torch_geometric.nn import global_mean_pool


class GCN(torch.nn.Module):
    def __init__(self, hidden_channels):
        super(GCN, self).__init__()
        torch.manual_seed(42)
        self.conv1 = SAGEConv(dataset.num_node_features, 2 * hidden_channels)
        self.conv2 = SAGEConv(2 * hidden_channels, 4 *  hidden_channels)
        self.conv3 = SAGEConv(4 * hidden_channels, 2 * hidden_channels)
        self.lin1 = Linear(2 * hidden_channels, hidden_channels)
        self.lin2 = Linear(hidden_channels, dataset.num_classes)

    def forward(self, x, edge_index, batch):
        x = self.conv1(x, edge_index)
        x = x.relu()
        x = self.conv2(x, edge_index)
        x = x.relu()
        x = self.conv3(x, edge_index)

        x = global_mean_pool(x, batch)  # [batch_size, hidden_channels]

        x = F.dropout(x, p=0.5, training=self.training)
        x = self.lin1(x)
        x = self.lin2(x)
        
        return x

# %%
model = GCN(hidden_channels=NUM_HIDDEN_CHANNELS)
print(model)
print("Number of parameters: ", sum(p.numel() for p in model.parameters()))

optimizer = torch.optim.Adam(model.parameters(), lr=0.005)
criterion = torch.nn.CrossEntropyLoss()

def train():
    model.train()

    for data in train_loader:
        out = model(data.x, data.edge_index, data.batch)
        loss = criterion(out, data.y)
        loss.backward()
        optimizer.step()
        optimizer.zero_grad()
        return loss

def test(loader):
    model.eval()
    correct = 0
    for data in loader:
        out = model(data.x, data.edge_index, data.batch)  
        pred = out.argmax(dim=1)
        correct += int((pred == data.y).sum())
    return correct / len(loader.dataset)

loss_values = []
train_acc_values = []
acc_values = []

for epoch in range(1, 251):
    loss = train()
    train_acc = test(train_loader)
    test_acc = test(test_loader)
        
    loss_values.append(loss)
    acc_values.append(test_acc)
    train_acc_values.append(train_acc)
    print(f'Epoch: {epoch:03d}, Loss: {loss:.4f}, Train Acc: {train_acc:.4f}, Test Acc: {test_acc:.4f}')
    if(test_acc > 0.81):
        break

plt.plot( acc_values, 'b', train_acc_values, 'g')
plt.show()
# Out:
# GCN(
#   (conv1): SAGEConv(1, 64)
#   (conv2): SAGEConv(64, 128)
#   (conv3): SAGEConv(128, 64)
#   (lin1): Linear(in_features=64, out_features=32, bias=True)
#   (lin2): Linear(in_features=32, out_features=9, bias=True)
# )
# Number of parameters:  35529
# Epoch: 001, Loss: 2.7130, Train Acc: 0.3636, Test Acc: 0.4318
# Epoch: 002, Loss: 2.5687, Train Acc: 0.3636, Test Acc: 0.4318
# Epoch: 003, Loss: 1.2973, Train Acc: 0.3485, Test Acc: 0.4318
# Epoch: 004, Loss: 2.6368, Train Acc: 0.4242, Test Acc: 0.5000
# Epoch: 005, Loss: 1.3590, Train Acc: 0.3788, Test Acc: 0.5000
# Epoch: 006, Loss: 2.3490, Train Acc: 0.3788, Test Acc: 0.4773
# Epoch: 007, Loss: 1.5863, Train Acc: 0.3788, Test Acc: 0.4545
# Epoch: 008, Loss: 2.0417, Train Acc: 0.4394, Test Acc: 0.5000
# Epoch: 009, Loss: 1.9638, Train Acc: 0.3939, Test Acc: 0.5000
# Epoch: 010, Loss: 2.0564, Train Acc: 0.4242, Test Acc: 0.5000
# Epoch: 011, Loss: 1.5922, Train Acc: 0.4242, Test Acc: 0.4545
# Epoch: 012, Loss: 2.3526, Train Acc: 0.4242, Test Acc: 0.4545
# Epoch: 013, Loss: 1.5861, Train Acc: 0.4242, Test Acc: 0.4545
# Epoch: 014, Loss: 3.0898, Train Acc: 0.3788, Test Acc: 0.4545
# Epoch: 015, Loss: 1.5579, Train Acc: 0.3788, Test Acc: 0.4545
# Epoch: 016, Loss: 1.6396, Train Acc: 0.3788, Test Acc: 0.4545
# Epoch: 017, Loss: 2.1234, Train Acc: 0.3939, Test Acc: 0.4773
# Epoch: 018, Loss: 1.7447, Train Acc: 0.3939, Test Acc: 0.4773
# Epoch: 019, Loss: 1.8780, Train Acc: 0.4697, Test Acc: 0.4773
# Epoch: 020, Loss: 1.8123, Train Acc: 0.4697, Test Acc: 0.5000
# Epoch: 021, Loss: 1.6866, Train Acc: 0.4848, Test Acc: 0.5000
# Epoch: 022, Loss: 1.3898, Train Acc: 0.5000, Test Acc: 0.5000
# Epoch: 023, Loss: 1.5311, Train Acc: 0.4242, Test Acc: 0.5000
# Epoch: 024, Loss: 1.2138, Train Acc: 0.4091, Test Acc: 0.4773
# Epoch: 025, Loss: 1.6156, Train Acc: 0.4091, Test Acc: 0.4773
# Epoch: 026, Loss: 1.7974, Train Acc: 0.4091, Test Acc: 0.4773
# Epoch: 027, Loss: 1.7566, Train Acc: 0.4242, Test Acc: 0.4773
# Epoch: 028, Loss: 2.1794, Train Acc: 0.4545, Test Acc: 0.4773
# Epoch: 029, Loss: 1.5166, Train Acc: 0.4242, Test Acc: 0.5000
# Epoch: 030, Loss: 1.4458, Train Acc: 0.3939, Test Acc: 0.5000
# Epoch: 031, Loss: 1.7523, Train Acc: 0.4394, Test Acc: 0.4318
# Epoch: 032, Loss: 1.9121, Train Acc: 0.4091, Test Acc: 0.3182
# Epoch: 033, Loss: 1.3118, Train Acc: 0.4091, Test Acc: 0.3182
# Epoch: 034, Loss: 1.7340, Train Acc: 0.4091, Test Acc: 0.3409
# Epoch: 035, Loss: 0.9935, Train Acc: 0.4697, Test Acc: 0.4545
# Epoch: 036, Loss: 1.0409, Train Acc: 0.4545, Test Acc: 0.5000
# Epoch: 037, Loss: 1.6982, Train Acc: 0.4545, Test Acc: 0.4773
# Epoch: 038, Loss: 1.7244, Train Acc: 0.4545, Test Acc: 0.4773
# Epoch: 039, Loss: 1.4288, Train Acc: 0.4545, Test Acc: 0.4773
# Epoch: 040, Loss: 1.6973, Train Acc: 0.4545, Test Acc: 0.4773
# Epoch: 041, Loss: 1.4149, Train Acc: 0.4545, Test Acc: 0.4773
# Epoch: 042, Loss: 1.6597, Train Acc: 0.4545, Test Acc: 0.5000
# Epoch: 043, Loss: 1.0903, Train Acc: 0.5000, Test Acc: 0.5227
# Epoch: 044, Loss: 1.1432, Train Acc: 0.5000, Test Acc: 0.5227
# Epoch: 045, Loss: 1.4648, Train Acc: 0.5303, Test Acc: 0.5227
# Epoch: 046, Loss: 1.5222, Train Acc: 0.5455, Test Acc: 0.5909
# Epoch: 047, Loss: 1.3498, Train Acc: 0.5758, Test Acc: 0.6136
# Epoch: 048, Loss: 1.6522, Train Acc: 0.5606, Test Acc: 0.6136
# Epoch: 049, Loss: 1.0040, Train Acc: 0.5758, Test Acc: 0.5682
# Epoch: 050, Loss: 1.5517, Train Acc: 0.5758, Test Acc: 0.5909
# Epoch: 051, Loss: 1.2133, Train Acc: 0.5758, Test Acc: 0.6136
# Epoch: 052, Loss: 1.1943, Train Acc: 0.5758, Test Acc: 0.5682
# Epoch: 053, Loss: 0.8713, Train Acc: 0.5455, Test Acc: 0.5682
# Epoch: 054, Loss: 1.2990, Train Acc: 0.5606, Test Acc: 0.5909
# Epoch: 055, Loss: 1.1496, Train Acc: 0.5455, Test Acc: 0.5682
# Epoch: 056, Loss: 1.1258, Train Acc: 0.5455, Test Acc: 0.5909
# Epoch: 057, Loss: 1.6463, Train Acc: 0.5606, Test Acc: 0.5909
# Epoch: 058, Loss: 1.5580, Train Acc: 0.5606, Test Acc: 0.5455
# Epoch: 059, Loss: 1.5346, Train Acc: 0.5606, Test Acc: 0.5455
# Epoch: 060, Loss: 1.0531, Train Acc: 0.6212, Test Acc: 0.6136
# Epoch: 061, Loss: 0.8039, Train Acc: 0.5758, Test Acc: 0.5909
# Epoch: 062, Loss: 1.0755, Train Acc: 0.5758, Test Acc: 0.5909
# Epoch: 063, Loss: 1.5867, Train Acc: 0.5606, Test Acc: 0.6136
# Epoch: 064, Loss: 1.8252, Train Acc: 0.6061, Test Acc: 0.6136
# Epoch: 065, Loss: 1.3998, Train Acc: 0.6364, Test Acc: 0.5909
# Epoch: 066, Loss: 1.3765, Train Acc: 0.6364, Test Acc: 0.5682
# Epoch: 067, Loss: 0.9745, Train Acc: 0.6364, Test Acc: 0.5909
# Epoch: 068, Loss: 1.2048, Train Acc: 0.6364, Test Acc: 0.6136
# Epoch: 069, Loss: 1.0009, Train Acc: 0.5758, Test Acc: 0.5455
# Epoch: 070, Loss: 1.3871, Train Acc: 0.5455, Test Acc: 0.5227
# Epoch: 071, Loss: 1.5435, Train Acc: 0.5606, Test Acc: 0.5455
# Epoch: 072, Loss: 1.0225, Train Acc: 0.5606, Test Acc: 0.5455
# Epoch: 073, Loss: 1.2977, Train Acc: 0.5909, Test Acc: 0.5455
# Epoch: 074, Loss: 1.1550, Train Acc: 0.5909, Test Acc: 0.5682
# Epoch: 075, Loss: 1.2347, Train Acc: 0.6212, Test Acc: 0.5909
# Epoch: 076, Loss: 0.8844, Train Acc: 0.6061, Test Acc: 0.5909
# Epoch: 077, Loss: 1.0342, Train Acc: 0.6364, Test Acc: 0.5909
# Epoch: 078, Loss: 1.1640, Train Acc: 0.6364, Test Acc: 0.5682
# Epoch: 079, Loss: 0.7094, Train Acc: 0.6364, Test Acc: 0.5682
# Epoch: 080, Loss: 1.2435, Train Acc: 0.6364, Test Acc: 0.5682
# Epoch: 081, Loss: 1.0954, Train Acc: 0.6212, Test Acc: 0.5909
# Epoch: 082, Loss: 1.0170, Train Acc: 0.5909, Test Acc: 0.6136
# Epoch: 083, Loss: 1.2503, Train Acc: 0.6818, Test Acc: 0.5909
# Epoch: 084, Loss: 1.4066, Train Acc: 0.6515, Test Acc: 0.6136
# Epoch: 085, Loss: 1.0989, Train Acc: 0.6364, Test Acc: 0.6136
# Epoch: 086, Loss: 0.7514, Train Acc: 0.5909, Test Acc: 0.5682
# Epoch: 087, Loss: 2.4318, Train Acc: 0.5909, Test Acc: 0.5227
# Epoch: 088, Loss: 1.6765, Train Acc: 0.6212, Test Acc: 0.5682
# Epoch: 089, Loss: 0.6476, Train Acc: 0.6212, Test Acc: 0.5682
# Epoch: 090, Loss: 0.8492, Train Acc: 0.6515, Test Acc: 0.5682
# Epoch: 091, Loss: 1.3625, Train Acc: 0.6212, Test Acc: 0.5455
# Epoch: 092, Loss: 0.7286, Train Acc: 0.6364, Test Acc: 0.5909
# Epoch: 093, Loss: 0.7779, Train Acc: 0.6061, Test Acc: 0.5909
# Epoch: 094, Loss: 0.3969, Train Acc: 0.6212, Test Acc: 0.5682
# Epoch: 095, Loss: 0.8876, Train Acc: 0.6364, Test Acc: 0.5682
# Epoch: 096, Loss: 0.7332, Train Acc: 0.6212, Test Acc: 0.5909
# Epoch: 097, Loss: 1.3349, Train Acc: 0.6364, Test Acc: 0.6591
# Epoch: 098, Loss: 0.9615, Train Acc: 0.6667, Test Acc: 0.5909
# Epoch: 099, Loss: 1.4489, Train Acc: 0.6818, Test Acc: 0.5909
# Epoch: 100, Loss: 1.5202, Train Acc: 0.6667, Test Acc: 0.6364
# Epoch: 101, Loss: 1.1153, Train Acc: 0.6364, Test Acc: 0.6364
# Epoch: 102, Loss: 1.2480, Train Acc: 0.6212, Test Acc: 0.6591
# Epoch: 103, Loss: 0.8193, Train Acc: 0.6212, Test Acc: 0.6364
# Epoch: 104, Loss: 1.0808, Train Acc: 0.6061, Test Acc: 0.6364
# Epoch: 105, Loss: 0.5787, Train Acc: 0.6212, Test Acc: 0.6136
# Epoch: 106, Loss: 0.8624, Train Acc: 0.6212, Test Acc: 0.6136
# Epoch: 107, Loss: 1.0554, Train Acc: 0.6364, Test Acc: 0.6136
# Epoch: 108, Loss: 0.8458, Train Acc: 0.6364, Test Acc: 0.6136
# Epoch: 109, Loss: 0.7153, Train Acc: 0.6515, Test Acc: 0.5909
# Epoch: 110, Loss: 0.7400, Train Acc: 0.6515, Test Acc: 0.5682
# Epoch: 111, Loss: 0.8420, Train Acc: 0.6515, Test Acc: 0.5682
# Epoch: 112, Loss: 1.3284, Train Acc: 0.6667, Test Acc: 0.5682
# Epoch: 113, Loss: 0.9660, Train Acc: 0.6970, Test Acc: 0.5682
# Epoch: 114, Loss: 0.5539, Train Acc: 0.6515, Test Acc: 0.5682
# Epoch: 115, Loss: 0.9843, Train Acc: 0.6667, Test Acc: 0.5909
# Epoch: 116, Loss: 0.9071, Train Acc: 0.6667, Test Acc: 0.6136
# Epoch: 117, Loss: 0.8192, Train Acc: 0.6818, Test Acc: 0.5909
# Epoch: 118, Loss: 0.6058, Train Acc: 0.7121, Test Acc: 0.5909
# Epoch: 119, Loss: 0.6445, Train Acc: 0.7424, Test Acc: 0.6136
# Epoch: 120, Loss: 0.4181, Train Acc: 0.7273, Test Acc: 0.6364
# Epoch: 121, Loss: 0.3649, Train Acc: 0.7424, Test Acc: 0.5909
# Epoch: 122, Loss: 1.1029, Train Acc: 0.6818, Test Acc: 0.5909
# Epoch: 123, Loss: 2.3831, Train Acc: 0.6212, Test Acc: 0.5909
# Epoch: 124, Loss: 2.0343, Train Acc: 0.6212, Test Acc: 0.6591
# Epoch: 125, Loss: 0.5498, Train Acc: 0.7121, Test Acc: 0.6591
# Epoch: 126, Loss: 0.2995, Train Acc: 0.7273, Test Acc: 0.5682
# Epoch: 127, Loss: 0.9263, Train Acc: 0.6515, Test Acc: 0.5227
# Epoch: 128, Loss: 1.2093, Train Acc: 0.6364, Test Acc: 0.5455
# Epoch: 129, Loss: 0.8120, Train Acc: 0.6061, Test Acc: 0.5227
# Epoch: 130, Loss: 0.2534, Train Acc: 0.5455, Test Acc: 0.4773
# Epoch: 131, Loss: 0.7176, Train Acc: 0.6364, Test Acc: 0.5227
# Epoch: 132, Loss: 1.0259, Train Acc: 0.7121, Test Acc: 0.5682
# Epoch: 133, Loss: 0.7988, Train Acc: 0.6364, Test Acc: 0.5227
# Epoch: 134, Loss: 1.3770, Train Acc: 0.6061, Test Acc: 0.5227
# Epoch: 135, Loss: 0.4934, Train Acc: 0.6667, Test Acc: 0.5455
# Epoch: 136, Loss: 1.2074, Train Acc: 0.6818, Test Acc: 0.5455
# Epoch: 137, Loss: 1.2381, Train Acc: 0.5758, Test Acc: 0.4091
# Epoch: 138, Loss: 1.8131, Train Acc: 0.5455, Test Acc: 0.2955
# Epoch: 139, Loss: 1.1257, Train Acc: 0.6212, Test Acc: 0.2955
# Epoch: 140, Loss: 0.7782, Train Acc: 0.7879, Test Acc: 0.5682
# Epoch: 141, Loss: 0.7452, Train Acc: 0.7727, Test Acc: 0.5909
# Epoch: 142, Loss: 0.7350, Train Acc: 0.6970, Test Acc: 0.5682
# Epoch: 143, Loss: 1.0246, Train Acc: 0.7121, Test Acc: 0.5909
# Epoch: 144, Loss: 1.4005, Train Acc: 0.7424, Test Acc: 0.5682
# Epoch: 145, Loss: 0.9119, Train Acc: 0.7424, Test Acc: 0.5227
# Epoch: 146, Loss: 0.7675, Train Acc: 0.7121, Test Acc: 0.4773
# Epoch: 147, Loss: 1.5566, Train Acc: 0.7273, Test Acc: 0.4773
# Epoch: 148, Loss: 0.3957, Train Acc: 0.6970, Test Acc: 0.5000
# Epoch: 149, Loss: 1.1633, Train Acc: 0.6970, Test Acc: 0.5227
# Epoch: 150, Loss: 1.2183, Train Acc: 0.7273, Test Acc: 0.4545
# Epoch: 151, Loss: 1.3429, Train Acc: 0.7121, Test Acc: 0.5000
# Epoch: 152, Loss: 1.1232, Train Acc: 0.6970, Test Acc: 0.5000
# Epoch: 153, Loss: 0.5545, Train Acc: 0.7121, Test Acc: 0.5227
# Epoch: 154, Loss: 0.5247, Train Acc: 0.7121, Test Acc: 0.4773
# Epoch: 155, Loss: 0.7080, Train Acc: 0.7424, Test Acc: 0.5455
# Epoch: 156, Loss: 0.8970, Train Acc: 0.7273, Test Acc: 0.5455
# Epoch: 157, Loss: 0.7420, Train Acc: 0.7273, Test Acc: 0.5227
# Epoch: 158, Loss: 1.0062, Train Acc: 0.7273, Test Acc: 0.5909
# Epoch: 159, Loss: 0.9187, Train Acc: 0.7576, Test Acc: 0.6364
# Epoch: 160, Loss: 0.7786, Train Acc: 0.7424, Test Acc: 0.6364
# Epoch: 161, Loss: 0.7915, Train Acc: 0.7424, Test Acc: 0.6818
# Epoch: 162, Loss: 0.7021, Train Acc: 0.7121, Test Acc: 0.6818
# Epoch: 163, Loss: 0.6550, Train Acc: 0.7121, Test Acc: 0.6818
# Epoch: 164, Loss: 0.8761, Train Acc: 0.7121, Test Acc: 0.6818
# Epoch: 165, Loss: 0.6280, Train Acc: 0.7424, Test Acc: 0.6818
# Epoch: 166, Loss: 0.4778, Train Acc: 0.7576, Test Acc: 0.6591
# Epoch: 167, Loss: 0.4440, Train Acc: 0.7727, Test Acc: 0.6364
# Epoch: 168, Loss: 0.7371, Train Acc: 0.7576, Test Acc: 0.6364
# Epoch: 169, Loss: 0.0730, Train Acc: 0.7121, Test Acc: 0.6136
# Epoch: 170, Loss: 0.6895, Train Acc: 0.7121, Test Acc: 0.6136
# Epoch: 171, Loss: 1.2647, Train Acc: 0.7121, Test Acc: 0.6136
# Epoch: 172, Loss: 0.5222, Train Acc: 0.6970, Test Acc: 0.6136
# Epoch: 173, Loss: 0.3399, Train Acc: 0.6970, Test Acc: 0.6136
# Epoch: 174, Loss: 0.6864, Train Acc: 0.6970, Test Acc: 0.5682
# Epoch: 175, Loss: 0.7383, Train Acc: 0.7121, Test Acc: 0.5909
# Epoch: 176, Loss: 1.2405, Train Acc: 0.7424, Test Acc: 0.6136
# Epoch: 177, Loss: 0.3418, Train Acc: 0.7727, Test Acc: 0.6136
# Epoch: 178, Loss: 0.5111, Train Acc: 0.7576, Test Acc: 0.6364
# Epoch: 179, Loss: 0.5689, Train Acc: 0.7576, Test Acc: 0.6364
# Epoch: 180, Loss: 0.7707, Train Acc: 0.7879, Test Acc: 0.6591
# Epoch: 181, Loss: 0.6640, Train Acc: 0.8030, Test Acc: 0.6591
# Epoch: 182, Loss: 0.8195, Train Acc: 0.8030, Test Acc: 0.6364
# Epoch: 183, Loss: 0.4470, Train Acc: 0.8182, Test Acc: 0.6364
# Epoch: 184, Loss: 0.6363, Train Acc: 0.8182, Test Acc: 0.6364
# Epoch: 185, Loss: 1.2974, Train Acc: 0.7727, Test Acc: 0.6136
# Epoch: 186, Loss: 0.7323, Train Acc: 0.7879, Test Acc: 0.5682
# Epoch: 187, Loss: 0.4953, Train Acc: 0.7727, Test Acc: 0.5682
# Epoch: 188, Loss: 0.3189, Train Acc: 0.7424, Test Acc: 0.5455
# Epoch: 189, Loss: 0.7627, Train Acc: 0.7424, Test Acc: 0.5455
# Epoch: 190, Loss: 0.6783, Train Acc: 0.7727, Test Acc: 0.5682
# Epoch: 191, Loss: 0.8345, Train Acc: 0.7879, Test Acc: 0.5682
# Epoch: 192, Loss: 0.7765, Train Acc: 0.7727, Test Acc: 0.5455
# Epoch: 193, Loss: 0.9426, Train Acc: 0.7727, Test Acc: 0.5682
# Epoch: 194, Loss: 0.6274, Train Acc: 0.8030, Test Acc: 0.6364
# Epoch: 195, Loss: 0.6097, Train Acc: 0.8182, Test Acc: 0.6818
# Epoch: 196, Loss: 0.6949, Train Acc: 0.8333, Test Acc: 0.6818
# Epoch: 197, Loss: 0.8511, Train Acc: 0.8182, Test Acc: 0.6818
# Epoch: 198, Loss: 0.2370, Train Acc: 0.7879, Test Acc: 0.6818
# Epoch: 199, Loss: 0.2135, Train Acc: 0.7727, Test Acc: 0.7045
# Epoch: 200, Loss: 0.8064, Train Acc: 0.7879, Test Acc: 0.7045
# Epoch: 201, Loss: 1.2315, Train Acc: 0.8182, Test Acc: 0.6818
# Epoch: 202, Loss: 0.1132, Train Acc: 0.8030, Test Acc: 0.6364
# Epoch: 203, Loss: 0.1905, Train Acc: 0.7879, Test Acc: 0.6364
# Epoch: 204, Loss: 0.0903, Train Acc: 0.7879, Test Acc: 0.6364
# Epoch: 205, Loss: 0.4602, Train Acc: 0.7879, Test Acc: 0.6364
# Epoch: 206, Loss: 0.5681, Train Acc: 0.7879, Test Acc: 0.6136
# Epoch: 207, Loss: 0.3047, Train Acc: 0.7576, Test Acc: 0.5909
# Epoch: 208, Loss: 0.4000, Train Acc: 0.7576, Test Acc: 0.5909
# Epoch: 209, Loss: 0.6479, Train Acc: 0.8333, Test Acc: 0.5909
# Epoch: 210, Loss: 0.1442, Train Acc: 0.8182, Test Acc: 0.6364
# Epoch: 211, Loss: 0.9614, Train Acc: 0.8030, Test Acc: 0.5909
# Epoch: 212, Loss: 0.1608, Train Acc: 0.8030, Test Acc: 0.6136
# Epoch: 213, Loss: 0.7952, Train Acc: 0.7727, Test Acc: 0.5909
# Epoch: 214, Loss: 0.0683, Train Acc: 0.7727, Test Acc: 0.5682
# Epoch: 215, Loss: 0.2659, Train Acc: 0.7879, Test Acc: 0.5682
# Epoch: 216, Loss: 0.2445, Train Acc: 0.8182, Test Acc: 0.6364
# Epoch: 217, Loss: 0.2405, Train Acc: 0.8333, Test Acc: 0.7045
# Epoch: 218, Loss: 0.6728, Train Acc: 0.8030, Test Acc: 0.7045
# Epoch: 219, Loss: 1.0597, Train Acc: 0.7727, Test Acc: 0.7273
# Epoch: 220, Loss: 0.4799, Train Acc: 0.7727, Test Acc: 0.7045
# Epoch: 221, Loss: 1.3418, Train Acc: 0.8485, Test Acc: 0.6591
# Epoch: 222, Loss: 0.2519, Train Acc: 0.8636, Test Acc: 0.6364
# Epoch: 223, Loss: 0.6487, Train Acc: 0.8333, Test Acc: 0.6136
# Epoch: 224, Loss: 0.6898, Train Acc: 0.7879, Test Acc: 0.5909
# Epoch: 225, Loss: 0.8267, Train Acc: 0.7879, Test Acc: 0.5682
# Epoch: 226, Loss: 0.5873, Train Acc: 0.8333, Test Acc: 0.6136
# Epoch: 227, Loss: 0.2769, Train Acc: 0.8485, Test Acc: 0.6364
# Epoch: 228, Loss: 0.0747, Train Acc: 0.8485, Test Acc: 0.6364
# Epoch: 229, Loss: 0.3377, Train Acc: 0.8333, Test Acc: 0.6364
# Epoch: 230, Loss: 0.3800, Train Acc: 0.8333, Test Acc: 0.6364
# Epoch: 231, Loss: 0.7032, Train Acc: 0.8030, Test Acc: 0.6364
# Epoch: 232, Loss: 0.2750, Train Acc: 0.8485, Test Acc: 0.6364
# Epoch: 233, Loss: 0.9701, Train Acc: 0.8485, Test Acc: 0.6364
# Epoch: 234, Loss: 0.2660, Train Acc: 0.8636, Test Acc: 0.6818
# Epoch: 235, Loss: 0.5096, Train Acc: 0.8788, Test Acc: 0.6364
# Epoch: 236, Loss: 0.7826, Train Acc: 0.8788, Test Acc: 0.6591
# Epoch: 237, Loss: 0.7057, Train Acc: 0.8788, Test Acc: 0.6591
# Epoch: 238, Loss: 0.2175, Train Acc: 0.8788, Test Acc: 0.6136
# Epoch: 239, Loss: 0.8081, Train Acc: 0.8788, Test Acc: 0.6136
# Epoch: 240, Loss: 0.4679, Train Acc: 0.8939, Test Acc: 0.6364
# Epoch: 241, Loss: 0.4567, Train Acc: 0.8939, Test Acc: 0.5909
# Epoch: 242, Loss: 0.4845, Train Acc: 0.8636, Test Acc: 0.6136
# Epoch: 243, Loss: 0.2529, Train Acc: 0.8333, Test Acc: 0.6136
# Epoch: 244, Loss: 0.4748, Train Acc: 0.8485, Test Acc: 0.6591
# Epoch: 245, Loss: 0.4512, Train Acc: 0.8636, Test Acc: 0.6591
# Epoch: 246, Loss: 0.2055, Train Acc: 0.8788, Test Acc: 0.6591
# Epoch: 247, Loss: 1.0657, Train Acc: 0.9091, Test Acc: 0.6818
# Epoch: 248, Loss: 0.3560, Train Acc: 0.8939, Test Acc: 0.6818
# Epoch: 249, Loss: 0.2263, Train Acc: 0.8636, Test Acc: 0.7045
# Epoch: 250, Loss: 0.4485, Train Acc: 0.8333, Test Acc: 0.7045

# %%
torch.save(model, 'models/model_gc.pth')

# %%
loaded_model = torch.load('models/model_gc.pth')

# %%
loaded_model.eval()
# Out:
# GCN(
#   (conv1): SAGEConv(1, 32)
#   (conv2): SAGEConv(32, 64)
#   (conv3): SAGEConv(64, 32)
#   (lin1): Linear(in_features=32, out_features=16, bias=True)
#   (lin2): Linear(in_features=16, out_features=10, bias=True)
# )

# %%
def test_loaded(loader):
    loaded_model.eval()
    correct = 0
    for data in loader:  # Iterate in batches over the training/test dataset.
        out = loaded_model(data.x, data.edge_index, data.batch)  
        pred = out.argmax(dim=1)  # Use the class with highest probability.
        correct += int((pred == data.y).sum())  # Check against ground-truth labels.
    return correct / len(loader.dataset)  # Derive ratio of correct predictions.

test_acc = test_loaded(test_loader)
print(f'Test Acc: {test_acc:.4f}')
# Out:
# Test Acc: 0.8718
